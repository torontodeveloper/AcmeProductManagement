# %% [markdown]
# <a href="https://colab.research.google.com/github/torontodeveloper/AcmeProductManagement/blob/master/DeepNetworkLab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
print(digits)
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
# ...

# %%
digits.images.shape
# Out:
# (1797, 8, 8)

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.target.shape
# Out:
# (1797,)

# %%
len(digits.images)
# Out:
# 1797

# %%
random_indices = np.random.choice(len(digits.images),9,replace=False)
fig,axes = plt.subplots(3,3,figsize=(6,6))
for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[random_indices[i]], cmap=plt.cm.gray_r, interpolation='nearest')
    ax.set_title(f"Label: {digits.target[random_indices[i]]}")

    # Removing axis labels
    ax.set_xticks([])
    ax.set_yticks([])

plt.show()
